# %%
import pandas as pd

#Init data
data1 = {
    'Make': ['atv/utv'],
    'Model':['all models'],
    'Vendor Code': ['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'MPN': ['AT-04118'],
    'AD ITEM NUMBER': ['127399'],
    'Vendor Notes': ['Ref : 27-1093'],
        }

#Lists of Models
list_models = [
    'DVX 400',
    'DVX 400 TS',
    'KFX400',
    'LT-Z400 QuadSport Z',
    'LT-Z400 QuadSport Z LE'


    
]

#Range of Years
years = list(range(2003, 2009))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in  years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
 #Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

#Print
final_df
# Out:
#        Make                   Model Vendor Code  \
# 0   atv/utv                 DVX 400        NACH
# 1   atv/utv              DVX 400 TS        NACH
# 2   atv/utv                  KFX400        NACH
# 3   atv/utv     LT-Z400 QuadSport Z        NACH
# 4   atv/utv  LT-Z400 QuadSport Z LE        NACH
# 5   atv/utv                 DVX 400        NACH
# 6   atv/utv              DVX 400 TS        NACH
# 7   atv/utv                  KFX400        NACH
# 8   atv/utv     LT-Z400 QuadSport Z        NACH
# 9   atv/utv  LT-Z400 QuadSport Z LE        NACH
# 10  atv/utv                 DVX 400        NACH
# 11  atv/utv              DVX 400 TS        NACH
# 12  atv/utv                  KFX400        NACH
# 13  atv/utv     LT-Z400 QuadSport Z        NACH
# 14  atv/utv  LT-Z400 QuadSport Z LE        NACH
# 15  atv/utv                 DVX 400        NACH
# 16  atv/utv              DVX 400 TS        NACH
# 17  atv/utv                  KFX400        NACH
# 18  atv/utv     LT-Z400 QuadSport Z        NACH
# 19  atv/utv  LT-Z400 QuadSport Z LE        NACH
# 20  atv/utv                 DVX 400        NACH
# 21  atv/utv              DVX 400 TS        NACH
# 22  atv/utv                  KFX400        NACH
# 23  atv/utv     LT-Z400 QuadSport Z        NACH
# 24  atv/utv  LT-Z400 QuadSport Z LE        NACH
# 25  atv/utv                 DVX 400        NACH
# 26  atv/utv              DVX 400 TS        NACH
# 27  atv/utv                  KFX400        NACH
# 28  atv/utv     LT-Z400 QuadSport Z        NACH
# 29  atv/utv  LT-Z400 QuadSport Z LE        NACH
#
#                       Vendor Name       MPN AD ITEM NUMBER   Vendor Notes  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 3   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 4   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 5   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 6   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 7   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 8   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 9   NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 10  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 11  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 12  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 13  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 14  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 15  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 16  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 17  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 18  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 19  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 20  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 21  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 22  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 23  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 24  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 25  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 26  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 27  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 28  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
# 29  NACHMAN INTERNATIONAL CO. LTD  AT-04118         127399  Ref : 27-1093
#
#     Year
# 0   2003
# 1   2003
# 2   2003
# 3   2003
# 4   2003
# 5   2004
# 6   2004
# 7   2004
# 8   2004
# 9   2004
# 10  2005
# 11  2005
# 12  2005
# 13  2005
# 14  2005
# 15  2006
# 16  2006
# 17  2006
# 18  2006
# 19  2006
# 20  2007
# 21  2007
# 22  2007
# 23  2007
# 24  2007
# 25  2008
# 26  2008
# 27  2008
# 28  2008
# 29  2008

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\14_Section 04 - Linkage Bearing Kits ( 10-13-22)\Merge\1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init data
data1 = {
    'Make': ['atv/utv'],
    'Model':['all models'],
    'Vendor Code': ['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'MPN': ['AT-04119'],
    'AD ITEM NUMBER': ['127400'],
    'Vendor Notes': ['Ref : 27-1150'],
        }

#Lists of Models
list_models = [
    'LT-R450 QuadRacer'



    
]

#Range of Years
years = list(range(2006, 2012))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in  years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
 #Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

#Print
final_df
# Out:
#       Make              Model Vendor Code                    Vendor Name  \
# 0  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  atv/utv  LT-R450 QuadRacer        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD ITEM NUMBER   Vendor Notes  Year
# 0  AT-04119         127400  Ref : 27-1150  2006
# 1  AT-04119         127400  Ref : 27-1150  2007
# 2  AT-04119         127400  Ref : 27-1150  2008
# 3  AT-04119         127400  Ref : 27-1150  2009
# 4  AT-04119         127400  Ref : 27-1150  2010
# 5  AT-04119         127400  Ref : 27-1150  2011

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\14_Section 04 - Linkage Bearing Kits ( 10-13-22)\Merge\2.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init data
data1 = {
    'Make': ['atv/utv'],
    'Model':['all models'],
    'Vendor Code': ['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'MPN': ['AT-04341'],
    'AD ITEM NUMBER': ['127401'],
    'Vendor Notes': ['Ref : 27-1141'],
        }

#Lists of Models
list_models = [
    'YFM350 Raptor'



    
]

#Range of Years
years = list(range(2004, 2014))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in  years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
 #Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

#Print
final_df
# Out:
#       Make          Model Vendor Code                    Vendor Name  \
# 0  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9  atv/utv  YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD ITEM NUMBER   Vendor Notes  Year
# 0  AT-04341         127401  Ref : 27-1141  2004
# 1  AT-04341         127401  Ref : 27-1141  2005
# 2  AT-04341         127401  Ref : 27-1141  2006
# 3  AT-04341         127401  Ref : 27-1141  2007
# 4  AT-04341         127401  Ref : 27-1141  2008
# 5  AT-04341         127401  Ref : 27-1141  2009
# 6  AT-04341         127401  Ref : 27-1141  2010
# 7  AT-04341         127401  Ref : 27-1141  2011
# 8  AT-04341         127401  Ref : 27-1141  2012
# 9  AT-04341         127401  Ref : 27-1141  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\SECTION 04\14_Section 04 - Linkage Bearing Kits ( 10-13-22)\Merge\3.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#Init data
data1 = {
    'Make': ['atv/utv'],
    'Model':['all models'],
    'Vendor Code': ['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    'MPN': ['AT-04342'],
    'AD ITEM NUMBER': ['127402'],
    'Vendor Notes': ['Ref : 27-1002'],
        }

#Lists of Models
list_models = [
    'YFM350X Warrior',
    'YFZ350 Banshee'




    
]

#Range of Years
years = list(range(1987, 2010))

#Functions to generate Dataframes for each model
def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate Dataframes for all sets of data
dfs = []
for year in  years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)
    
 #Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index=True)

#Print
final_df
# Out:
#        Make            Model Vendor Code                    Vendor Name  \
# 0   atv/utv  YFM350X Warrior        NACH  NACHMAN INTERNATIONAL CO. LTD
#